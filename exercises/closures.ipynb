// %% [markdown]
// # Closures
//
// ## Capturing

// %% [markdown]
// 1.

// %%
/* Make it work with least amount of changes*/
fn main() {
    let color = String::from("green");

    let print = move || println!("`color`: {}", color);

    print();
    print();

    // `color` can be borrowed immutably again, because the closure only holds
    // an immutable reference to `color`. 
    let _reborrow = &color;

    println!("{}",color);
}

main();
// Out:
// [E0382] Error: borrow of moved value: `color`
//     ╭─[ command_7:1:1 ]
//     │
//   3 │     let color = String::from("green");
//     │         ──┬──
//     │           ╰──── move occurs because `color` has type `String`, which does not implement the `Copy` trait
//     │
//   5 │     let print = move || println!("`color`: {}", color);
//     │                 ───┬───                         ──┬──
//     │                    ╰─────────────────────────────────── value moved into closure here
//     │                                                   │
//     │                                                   ╰──── variable moved due to use in closure
//     │
//  12 │     let _reborrow = &color;
//     │                     ───┬──
//     │                        ╰──── value borrowed here after move
// ────╯

// %% [markdown]
// 2.

// %%
/* Make it work 
- Dont use `_reborrow` and `_count_reborrowed`
- Dont modify `assert_eq`
*/
fn main() {
    let mut count = 0;

    let mut inc = || {
        count += 1;
        println!("`count`: {}", count);
    };

    inc();


    let _reborrow = &count; 

    inc();

    // The closure no longer needs to borrow `&mut count`. Therefore, it is
    // possible to reborrow without an error
    let _count_reborrowed = &mut count; 

    assert_eq!(count, 0);

    println!("SUCCESS");
}

main();
// Out:
// [E0502] Error: cannot borrow `count` as immutable because it is also borrowed as mutable
//     ╭─[ command_6:1:1 ]
//     │
//   8 │     let mut inc = || {
//     │                   ─┬
//     │                    ╰── mutable borrow occurs here
//   9 │         count += 1;
//     │         ──┬──
//     │           ╰──── first borrow occurs due to use of `count` in closure
//     │
//  16 │     let _reborrow = &count;
//     │                     ───┬──
//     │                        ╰──── immutable borrow occurs here
//     │
//  18 │     inc();
//     │     ─┬─
//     │      ╰─── mutable borrow later used here
// ────╯

// %% [markdown]
// ## Functions as Arguments

// %% [markdown]
// 3.

// %%
/* Implement `call_me` to make it work */
fn call_me {
    f();
}

fn function() {
    println!("I'm a function!");
}

fn main() {
    let closure = || println!("I'm a closure!");

    call_me(closure);
    call_me(function);

    println!("SUCCESS");
}

main();
// Out:
// Error: missing parameters for function definition
//    ╭─[ command_12:1:1 ]
//    │
//  2 │ fn call_me {
//    │           │
//    │           ╰─ error: missing parameters for function definition
//    │           │
//    │           ╰─ help: add a parameter list: `()`
// ───╯
// [E0425] Error: cannot find function `f` in this scope
//    ╭─[ command_12:1:1 ]
//    │
//  3 │     f();
//    │     ┬
//    │     ╰── not found in this scope
// ───╯
// [E0061] Error: this function takes 0 arguments but 1 argument was supplied
//     ╭─[ command_12:1:1 ]
//     │
//   2 │ fn call_me {
//     │    ───┬───
//     │       ╰───── note: function defined here
//     │
//  13 │     call_me(closure);
//     │     ───┬─── ───┬───
//     │        ╰───────────── error: this function takes 0 arguments but 1 argument was supplied
//     │                │
//     │                ╰───── unexpected argument of type `{closure@src\lib.rs:12:19: 12:21}`
//     │                │
//     │                ╰───── help: remove the extra argument: ``
// ────╯
// [E0061] Error: this function takes 0 arguments but 1 argument was supplied
//     ╭─[ command_12:1:1 ]
//     │
//   2 │ fn call_me {
//     │    ───┬───
//     │       ╰───── note: function defined here
//     │
//  14 │     call_me(function);
//     │     ───┬─── ────┬───
//     │        ╰────────────── error: this function takes 0 arguments but 1 argument was supplied
//     │                 │
//     │                 ╰───── unexpected argument of type `fn() {function}`
//     │                 │
//     │                 ╰───── help: remove the extra argument: ``
// ────╯

// %% [markdown]
// 4.

// %%
/* Fill in the blank */
fn main() {
    let mut s = String::from("SUCCESS");

    let update_string = |str| -> String { s.push_str(str); s };

    let result = exec(update_string);

    println!("{}", result);
}

fn exec<'a, ___>(f: F) -> String {
    f("!!!")
}

main();
// Out:
// SUCCESS!!!

// %% [markdown]
// ## Closures as Return Types

// %% [markdown]
// 5.

// %%
/* Fill in the blank using two approaches,
 and fix the error */
fn create_fn() -> ___ {
    let num = 5;

    // How does the following closure capture the environment variable `num`
    // &T, &mut T, T ?
    |x| x + num
}


fn main() {
    let fn_plain = create_fn();
    fn_plain(1);

    println!("SUCCESS");
}

main();
// Out:
// SUCCESS

// %% [markdown]
// 6.

// %%
/* Fill in the blank and fix the error*/
fn factory(x:i32) -> ___ {

    let num = 5;

    if x > 1{
        Box::new(move |x| x + num)
    } else {
        Box::new(move |x| x + num)
    }
}

fn main() {
    let fn_boxed = factory(2);
    fn_boxed(1);

    println!("SUCCESS");
}

main();
// Out:
// SUCCESS
